# %% [markdown]
# # `load-data.ipynb`

# %% [markdown]
# # Sharpic Dataset

# %% [markdown]
# ## Load raw data from CSVs

# %%
from pathlib import Path
import duckdb

# set the root directory where the CSV files are located
cwd = Path().cwd()
root_dir = Path(Path(cwd / '..').absolute())
# Raw data
raw_data_dir = root_dir / '_raw_data' / 'sharpicManU' / 'Glucose Data'
# formatted data
formatted_data_dir = root_dir / '_data' / 'sharpicManU'
# load data from csvs:
csv_paths = str(raw_data_dir / '*.csv')
df_all = duckdb.from_csv_auto(csv_paths, filename=True)

# %% [markdown]
# ### Show full dataset

# %%
df_all
# Out:
# ┌──────────────────┬────────┬───────────────────────────────────────────────────────────────────────────────────────────┐
# │      bg_ts       │ value  │                                         filename                                          │
# │     varchar      │ double │                                          varchar                                          │
# ├──────────────────┼────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │ 01/10/2023 00:04 │    7.5 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:09 │    8.0 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:14 │    8.6 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:19 │    9.2 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:24 │    9.7 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:29 │   10.1 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:34 │   10.6 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:39 │   11.1 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:44 │   11.9 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:49 │   13.4 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │        ·         │     ·  │                                             ·                                             │
# │        ·         │     ·  │                                             ·                                             │
# │        ·         │     ·  │                                             ·                                             │
# │ 05/11/2023 01:09 │    4.2 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:14 │    4.4 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:19 │    4.6 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:24 │    4.9 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:29 │    5.1 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:34 │    5.2 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:39 │    5.5 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:44 │    5.7 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:49 │    6.0 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:54 │    6.3 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# ├──────────────────┴────────┴───────────────────────────────────────────────────────────────────────────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                               3 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
df_view = df_all.create_view('glucose_data')
df_view.describe()
# Out:
# ┌─────────┬──────────────────┬────────────────────┐
# │  aggr   │      bg_ts       │       value        │
# │ varchar │     varchar      │       double       │
# ├─────────┼──────────────────┼────────────────────┤
# │ count   │ 356146           │           356146.0 │
# │ mean    │ NULL             │  8.190111663007224 │
# │ stddev  │ NULL             │ 3.1559837370187664 │
# │ min     │ 01/01/2024 00:00 │                0.1 │
# │ max     │ 31/12/2023 23:59 │               27.8 │
# │ median  │ NULL             │                7.5 │
# └─────────┴──────────────────┴────────────────────┘

# %%
df_view
# Out:
# ┌──────────────────┬────────┬───────────────────────────────────────────────────────────────────────────────────────────┐
# │      bg_ts       │ value  │                                         filename                                          │
# │     varchar      │ double │                                          varchar                                          │
# ├──────────────────┼────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │ 01/10/2023 00:04 │    7.5 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:09 │    8.0 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:14 │    8.6 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:19 │    9.2 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:24 │    9.7 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:29 │   10.1 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:34 │   10.6 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:39 │   11.1 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:44 │   11.9 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 01/10/2023 00:49 │   13.4 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │        ·         │     ·  │                                             ·                                             │
# │        ·         │     ·  │                                             ·                                             │
# │        ·         │     ·  │                                             ·                                             │
# │ 05/11/2023 01:09 │    4.2 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:14 │    4.4 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:19 │    4.6 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:24 │    4.9 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:29 │    5.1 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:34 │    5.2 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:39 │    5.5 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:44 │    5.7 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:49 │    6.0 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# │ 05/11/2023 01:54 │    6.3 │ /home/robbiec/Git/Data/notebooks/../_raw_data/sharpicManU/Glucose Data/UoMGlucose2301.csv │
# ├──────────────────┴────────┴───────────────────────────────────────────────────────────────────────────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                               3 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## Export to parquet

# %%
# Use DuckDB's COPY command for efficient Parquet export
parquet_path = str(formatted_data_dir / 'GlucoseData.parquet')
duckdb.sql(f"""
    COPY glucose_data TO '{parquet_path}'
    (FORMAT PARQUET, COMPRESSION 'SNAPPY', PARTITION_BY (filename), OVERWRITE_OR_IGNORE TRUE)
""")
print(f"Data exported to {parquet_path}")
# Out:
# Data exported to /home/robbiec/Git/Data/notebooks/../_data/sharpicManU/GlucoseData.parquet

# %% [markdown]
# ## Export to `postgres`

# %%
from getpass import getpass

# PostgreSQL connection string
pg_password = getpass("Enter PostgreSQL password: ")
pg_conn_str = f"postgresql://postgres:{pg_password}@192.168.7.221:5432/pfun"

# %%
# Export DuckDB view/table to PostgreSQL
import pandas as pd

# Convert DuckDB view to Pandas DataFrame
df = df_view.to_df()
df.head()
# Out:
#               bg_ts  value                                           filename
# 0  01/10/2023 00:04    7.5  /home/robbiec/Git/Data/notebooks/../_raw_data/...
# 1  01/10/2023 00:09    8.0  /home/robbiec/Git/Data/notebooks/../_raw_data/...
# 2  01/10/2023 00:14    8.6  /home/robbiec/Git/Data/notebooks/../_raw_data/...
# 3  01/10/2023 00:19    9.2  /home/robbiec/Git/Data/notebooks/../_raw_data/...
# 4  01/10/2023 00:24    9.7  /home/robbiec/Git/Data/notebooks/../_raw_data/...

# %%
import os
df['filename'] = df['filename'].apply(lambda filename: Path(filename).name)

# %%
df.head()
# Out:
#               bg_ts  value            filename
# 0  01/10/2023 00:04    7.5  UoMGlucose2301.csv
# 1  01/10/2023 00:09    8.0  UoMGlucose2301.csv
# 2  01/10/2023 00:14    8.6  UoMGlucose2301.csv
# 3  01/10/2023 00:19    9.2  UoMGlucose2301.csv
# 4  01/10/2023 00:24    9.7  UoMGlucose2301.csv

# %%
# Export DataFrame to PostgreSQL
df.to_sql('sharpic_glucose_data', con=pg_conn_str, if_exists='replace', index=False)
# Out:
# 146

# %% [markdown]
# ### Check that the data exists in postgres

# %%
df_smol = pd.read_sql_query("SELECT * FROM sharpic_glucose_data LIMIT 5;", con=pg_conn_str)

df_smol
# Out:
#               bg_ts  value            filename
# 0  01/10/2023 00:04    7.5  UoMGlucose2301.csv
# 1  01/10/2023 00:09    8.0  UoMGlucose2301.csv
# 2  01/10/2023 00:14    8.6  UoMGlucose2301.csv
# 3  01/10/2023 00:19    9.2  UoMGlucose2301.csv
# 4  01/10/2023 00:24    9.7  UoMGlucose2301.csv

# %% [markdown]
# ---

# %% [markdown]
# # Dexcom Dataset

# %% [markdown]
# ## Load Dexcom data from CSV

# %%
from pathlib import Path
import duckdb

# get the directory where the CSV files are located
raw_data_dir = root_dir / '_raw_data' / 'dexcom'

# load data from csvs:
csv_paths = str(raw_data_dir / '*.csv')
df_all = duckdb.from_csv_auto(csv_paths, filename=True)

# %%
df_all
# Out:
# ┌──────────┬─────────────────────┬─────────────────────┬───────┬────────┬───────┬──────────┬──────────────┬────────────────┬─────────────────┬────────────────┬───────────────┬─────────────────────────────────────────────────────────────────────┐
# │ user_id  │       ts_utc        │      ts_local       │ is_sg │   sg   │ is_fl │ meal_tag │ tag_bef_meal │ tag_after_meal │ tag_after_snack │ tag_seems_high │ tag_seems_low │                              filename                               │
# │  int64   │      timestamp      │      timestamp      │ int64 │ double │ int64 │ varchar  │   boolean    │    boolean     │     boolean     │    boolean     │    boolean    │                               varchar                               │
# ├──────────┼─────────────────────┼─────────────────────┼───────┼────────┼───────┼──────────┼──────────────┼────────────────┼─────────────────┼────────────────┼───────────────┼─────────────────────────────────────────────────────────────────────┤
# │ 10130489 │ 2021-01-18 09:48:09 │ 2021-01-18 01:48:09 │     1 │  112.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 09:53:08 │ 2021-01-18 01:53:08 │     1 │  102.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ true          │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 09:58:08 │ 2021-01-18 01:58:08 │     1 │   99.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ true          │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:03:09 │ 2021-01-18 02:03:09 │     1 │  101.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ true          │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:08:08 │ 2021-01-18 02:08:08 │     1 │  102.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ true          │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:13:09 │ 2021-01-18 02:13:09 │     1 │  102.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ true          │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:18:08 │ 2021-01-18 02:18:08 │     1 │  103.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:23:09 │ 2021-01-18 02:23:09 │     1 │  107.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:28:08 │ 2021-01-18 02:28:08 │     1 │  108.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:33:08 │ 2021-01-18 02:33:08 │     1 │  111.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │     ·    │          ·          │          ·          │     · │    ·   │     · │  ·       │  ·           │   ·            │   ·             │  ·             │   ·           │                                  ·                                  │
# │     ·    │          ·          │          ·          │     · │    ·   │     · │  ·       │  ·           │   ·            │   ·             │  ·             │   ·           │                                  ·                                  │
# │     ·    │          ·          │          ·          │     · │    ·   │     · │  ·       │  ·           │   ·            │   ·             │  ·             │   ·           │                                  ·                                  │
# │ 10130489 │ 2021-01-28 06:43:28 │ 2021-01-27 22:43:28 │     1 │  148.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 06:48:28 │ 2021-01-27 22:48:28 │     1 │  145.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 06:53:28 │ 2021-01-27 22:53:28 │     1 │  143.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 06:58:28 │ 2021-01-27 22:58:28 │     1 │  140.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 07:03:28 │ 2021-01-27 23:03:28 │     1 │  141.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 07:08:28 │ 2021-01-27 23:08:28 │     1 │  140.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 07:13:28 │ 2021-01-27 23:13:28 │     1 │  142.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 07:18:28 │ 2021-01-27 23:18:28 │     1 │  142.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 07:23:28 │ 2021-01-27 23:23:28 │     1 │  142.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 07:28:28 │ 2021-01-27 23:28:28 │     1 │  121.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# ├──────────┴─────────────────────┴─────────────────────┴───────┴────────┴───────┴──────────┴──────────────┴────────────────┴─────────────────┴────────────────┴───────────────┴─────────────────────────────────────────────────────────────────────┤
# │ 2879 rows (20 shown)                                                                                                                                                                                                                   13 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
df_view = df_all.create_view('dexcom_glucose_data')
df_view.describe()
# Out:
# ┌─────────┬────────────┬─────────────────────┬─────────────────────┬────────────────────┬────────────────────┬──────────────────────┬───────────┬──────────────┬────────────────┬─────────────────┬────────────────┬───────────────┐
# │  aggr   │  user_id   │       ts_utc        │      ts_local       │       is_sg        │         sg         │        is_fl         │ meal_tag  │ tag_bef_meal │ tag_after_meal │ tag_after_snack │ tag_seems_high │ tag_seems_low │
# │ varchar │   double   │       varchar       │       varchar       │       double       │       double       │        double        │  varchar  │   varchar    │    varchar     │     varchar     │    varchar     │    varchar    │
# ├─────────┼────────────┼─────────────────────┼─────────────────────┼────────────────────┼────────────────────┼──────────────────────┼───────────┼──────────────┼────────────────┼─────────────────┼────────────────┼───────────────┤
# │ count   │     2879.0 │ 2879                │ 2879                │             2879.0 │             2850.0 │               2879.0 │ 29        │ 2879         │ 2879           │ 2879            │ 2879           │ 2879          │
# │ mean    │ 10130489.0 │ NULL                │ NULL                │ 0.9899270580062521 │ 120.26701754385965 │ 0.010072941993747829 │ NULL      │ NULL         │ NULL           │ NULL            │ NULL           │ NULL          │
# │ stddev  │        0.0 │ NULL                │ NULL                │ 0.0998746342075374 │  17.70932373912085 │  0.09987463420753737 │ NULL      │ NULL         │ NULL           │ NULL            │ NULL           │ NULL          │
# │ min     │ 10130489.0 │ 2021-01-18 09:48:09 │ 2021-01-18 01:48:09 │                0.0 │               95.0 │                  0.0 │ Breakfast │ false        │ false          │ false           │ false          │ false         │
# │ max     │ 10130489.0 │ 2021-01-28 07:28:28 │ 2021-01-27 23:28:28 │                1.0 │              262.0 │                  1.0 │ Snack     │ true         │ true           │ true            │ true           │ true          │
# │ median  │ 10130489.0 │ NULL                │ NULL                │                1.0 │              115.0 │                  0.0 │ NULL      │ NULL         │ NULL           │ NULL            │ NULL           │ NULL          │
# └─────────┴────────────┴─────────────────────┴─────────────────────┴────────────────────┴────────────────────┴──────────────────────┴───────────┴──────────────┴────────────────┴─────────────────┴────────────────┴───────────────┘

# %%
df_view
# Out:
# ┌──────────┬─────────────────────┬─────────────────────┬───────┬────────┬───────┬──────────┬──────────────┬────────────────┬─────────────────┬────────────────┬───────────────┬─────────────────────────────────────────────────────────────────────┐
# │ user_id  │       ts_utc        │      ts_local       │ is_sg │   sg   │ is_fl │ meal_tag │ tag_bef_meal │ tag_after_meal │ tag_after_snack │ tag_seems_high │ tag_seems_low │                              filename                               │
# │  int64   │      timestamp      │      timestamp      │ int64 │ double │ int64 │ varchar  │   boolean    │    boolean     │     boolean     │    boolean     │    boolean    │                               varchar                               │
# ├──────────┼─────────────────────┼─────────────────────┼───────┼────────┼───────┼──────────┼──────────────┼────────────────┼─────────────────┼────────────────┼───────────────┼─────────────────────────────────────────────────────────────────────┤
# │ 10130489 │ 2021-01-18 09:48:09 │ 2021-01-18 01:48:09 │     1 │  112.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 09:53:08 │ 2021-01-18 01:53:08 │     1 │  102.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ true          │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 09:58:08 │ 2021-01-18 01:58:08 │     1 │   99.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ true          │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:03:09 │ 2021-01-18 02:03:09 │     1 │  101.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ true          │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:08:08 │ 2021-01-18 02:08:08 │     1 │  102.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ true          │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:13:09 │ 2021-01-18 02:13:09 │     1 │  102.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ true          │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:18:08 │ 2021-01-18 02:18:08 │     1 │  103.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:23:09 │ 2021-01-18 02:23:09 │     1 │  107.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:28:08 │ 2021-01-18 02:28:08 │     1 │  108.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-18 10:33:08 │ 2021-01-18 02:33:08 │     1 │  111.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │     ·    │          ·          │          ·          │     · │    ·   │     · │  ·       │  ·           │   ·            │   ·             │  ·             │   ·           │                                  ·                                  │
# │     ·    │          ·          │          ·          │     · │    ·   │     · │  ·       │  ·           │   ·            │   ·             │  ·             │   ·           │                                  ·                                  │
# │     ·    │          ·          │          ·          │     · │    ·   │     · │  ·       │  ·           │   ·            │   ·             │  ·             │   ·           │                                  ·                                  │
# │ 10130489 │ 2021-01-28 06:43:28 │ 2021-01-27 22:43:28 │     1 │  148.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 06:48:28 │ 2021-01-27 22:48:28 │     1 │  145.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 06:53:28 │ 2021-01-27 22:53:28 │     1 │  143.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 06:58:28 │ 2021-01-27 22:58:28 │     1 │  140.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 07:03:28 │ 2021-01-27 23:03:28 │     1 │  141.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 07:08:28 │ 2021-01-27 23:08:28 │     1 │  140.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 07:13:28 │ 2021-01-27 23:13:28 │     1 │  142.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 07:18:28 │ 2021-01-27 23:18:28 │     1 │  142.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 07:23:28 │ 2021-01-27 23:23:28 │     1 │  142.0 │     0 │ NULL     │ true         │ false          │ false           │ true           │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# │ 10130489 │ 2021-01-28 07:28:28 │ 2021-01-27 23:28:28 │     1 │  121.0 │     0 │ NULL     │ true         │ false          │ false           │ false          │ false         │ /home/robbiec/Git/Data/notebooks/../_raw_data/dexcom/valid_data.csv │
# ├──────────┴─────────────────────┴─────────────────────┴───────┴────────┴───────┴──────────┴──────────────┴────────────────┴─────────────────┴────────────────┴───────────────┴─────────────────────────────────────────────────────────────────────┤
# │ 2879 rows (20 shown)                                                                                                                                                                                                                   13 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## Export to parquet

# %%
# Use DuckDB's COPY command for efficient Parquet export
parquet_path = str(root_dir / '_data' / 'dexcom' / 'valid_data.parquet')
duckdb.sql(f"""
    COPY glucose_data TO '{parquet_path}'
    (FORMAT PARQUET, COMPRESSION 'SNAPPY', PARTITION_BY (filename), OVERWRITE_OR_IGNORE TRUE)
""")
print(f"Data exported to {parquet_path}")
# Out:
# Data exported to /home/robbiec/Git/Data/notebooks/../_data/dexcom/valid_data.parquet

# %% [markdown]
# ## Export to `postgres`

# %%
# from getpass import getpass

# # PostgreSQL connection string
# pg_password = getpass("Enter PostgreSQL password: ")
# pg_conn_str = f"postgresql://postgres:{pg_password}@192.168.7.221:5432/pfun"

# %%
# Export DuckDB view/table to PostgreSQL
import pandas as pd

# Convert DuckDB view to Pandas DataFrame
df = df_view.to_df()
# Out:
# 879

# %%
# reformat filename col
df['filename'] = df['filename'].apply(lambda filename: Path(filename).name)

# %%
# Export DataFrame to PostgreSQL
df.to_sql('dexcom_glucose_data', con=pg_conn_str, if_exists='replace', index=False)
# Out:
# 879

# %% [markdown]
# ### Check that the dexcom data exists in postgres

# %%
df_smol = pd.read_sql_query("SELECT * FROM dexcom_glucose_data LIMIT 5;", con=pg_conn_str)

df_smol
# Out:
#     user_id              ts_utc            ts_local  is_sg     sg  is_fl  \
# 0  10130489 2021-01-18 09:48:09 2021-01-18 01:48:09      1  112.0      0
# 1  10130489 2021-01-18 09:53:08 2021-01-18 01:53:08      1  102.0      0
# 2  10130489 2021-01-18 09:58:08 2021-01-18 01:58:08      1   99.0      0
# 3  10130489 2021-01-18 10:03:09 2021-01-18 02:03:09      1  101.0      0
# 4  10130489 2021-01-18 10:08:08 2021-01-18 02:08:08      1  102.0      0
#
#   meal_tag  tag_bef_meal  tag_after_meal  tag_after_snack  tag_seems_high  \
# 0     None          True           False            False           False
# 1     None          True           False            False           False
# 2     None          True           False            False           False
# 3     None          True           False            False           False
# 4     None          True           False            False           False
#
#    tag_seems_low        filename
# 0          False  valid_data.csv
# 1           True  valid_data.csv
# 2           True  valid_data.csv
# 3           True  valid_data.csv
# 4           True  valid_data.csv
